# %%
import statistics
import pandas as pd
import numpy as np
from scipy import stats

import matplotlib.pyplot as plt

# %%
burger = 24000
pizza = 52000
dimsum = 30000
ekado = 7500
milkshake = 10000
eskrim = 15000

print("     soal 1     ")
burger1 = 6
pizza1 = 3
dimsum1 = 4
ekado1 = 4
milkshake1 = 2
es1 = 5
js = (burger1 * burger)+(pizza1 * pizza)+(dimsum1 * dimsum)+(ekado1 * ekado)+(milkshake1 * milkshake)+(es1 * eskrim)
jm = (burger1 + pizza1 + dimsum1 + ekado1 + milkshake1 + es1) 
print("maka semua jumlah harga makanan yang di pesan adalah : " + str(js))
print("maka jumlah belanjaan : " + str (jm))
print()

print("     soal 2     ")
jm1 = (burger1 + pizza + dimsum1 + ekado1 + milkshake1 + es1)
f1 = burger1 / jm *100
f2 = pizza1 / jm * 100
f3 = dimsum1 / jm * 100
f4 = ekado1 / jm * 100
f5 = milkshake1 / jm * 100
f6 = es1 / jm * 100

print("burger1 " +str(f1))
print("pizza1 " +str(f2))
print("dimsum1 " +str(f3))
print("ekado1 " +str(f4))
print("milkshake1 " +str(f5))
print("es1 " +str(f6))
print()

# PIECART
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("JUMLAH BELANJAAN")
jurusan = ['burger', 'pizza', 'dimsum', 'ekado', 'milkshake', 'eskrim']
siswa = [25.0, 12.5, 16.666666666666664, 16.666666666666664, 8.333333333333332, 20.833333333333336]
ax.pie(siswa,labels=jurusan,autopct='%1.2f%%')
plt.show()
print()

print("     soal 3     ")
print("ahmad")
ba = 4
pa = 2
ja = 7.5

jml1 = (0.70 * ((ba * 24000) + (pa * 52000 )) + (7.5 * 2000)) - 5000
print("maka jumlah belanjaan ahmad : " +str (jml1))
ka = (200000 - jml1)
print("maka jumlah kembalian ahmad adalah : " + str(ka))
print()

print("beni")
db = 3
eb = 1
mb = 2
jb = 4

jml2 = (0.70 * ((db * 30000) + (eb * 15000) + (mb * 10000))) + (jb * 1800 ) - 5000
print("maka total belanjaan beni adalah : " + str (jml2))
kb = (150000 - jml2)
print("maka jumlah kembalian beni adalah : " +str (kb))
print()

print("citra")
ec = 3
jc = 8
jml3 = (ec * 15000) + (jc * 2000) - 5000
print("maka total belanjaan citra adalah : " +str(jml3))
kc = (60000 - jml3)
print("maka kembalian citra adalah : " +str(kc))
print()

print("dadang")
bd = 2
dd = 1
jd = 5

jml4 = (0.80 * ((bd * 24000) + (dd * 30000))) + (jd * 1800 ) - 5000
print("maka total belanjaan dadang adalah : " + str (jml4))
kd = (100000 - jml4)
print("maka jumlah kembalian beni adalah : " +str (kd))
print()

print("epen")
ee = 4
ese = 1
pe = 1
je = 12

jml5 = (0.70 * ((ee * 7500) + (ese * 15000) + (pe * 52000))) + (je * 2200 ) - 5000
print("maka total belanjaan dadang adalah : " + str (jml5))
kd = (100000 - jml5)
print("maka jumlah kembalian beni adalah : " +str (kd))
print()

print("     soal 4     ")
ba = 4
pa = 2
jlma = (0.30 * ((ba * 24000) + (pa * 52000))) + 5000
print("maka jumlah potongan ahmad adalah : " +str(jlma))
print()

db = 3
eb = 1
mb = 2
jlmb = (0.30 * (db * 30000) + (eb * 7500) + (mb * 10000)) + 5000
print("maka jumlah potongan beni adalah : " +str(jlmb))
print()

ec = 3
jlmc = (0.20 * (ec * 15000)) + 5000
print("maka jumlah potongan citra adalah : " +str(jlmc))
print()

bd = 2
dd = 1
jlmd = (0.30 * (bd * 24000) + (dd * 30000)) + 5000
print("maka jumlah potongan dadang adalah : " +str(jlmc))
print()

ee = 4
ese = 1
pe = 1
jlme = (0.30 * (ee * 7500) + (ese * 15000) + (pe * 52000)) + 5000
print("maka jumlah potongan epen adalah : " +str(jlme))
print()
sj = (jlma + jlmb + jlmc + jlmd + jlme)
print(" jumlah : " +str(sj))
print()

print("     soal 5     ")
print()
a = 7.5
b = 2000
c = 4
d = 1800
e = 8
f = 2000
g = 5
h = 1800
i = 12
j = 2200

jlms = (a * b)+(c * d)+(e * f)+(g * h)+(i * j)
print("maka total seluruh adalah : " +str(jlms))
# Out:
#      soal 1
# maka semua jumlah harga makanan yang di pesan adalah : 545000
# maka jumlah belanjaan : 24
#
#      soal 2
# burger1 25.0
# pizza1 12.5
# dimsum1 16.666666666666664
# ekado1 16.666666666666664
# milkshake1 8.333333333333332
# es1 20.833333333333336
#      soal 3
# ahmad
# maka jumlah belanjaan ahmad : 150000.0
# maka jumlah kembalian ahmad adalah : 50000.0
#
# beni
# maka total belanjaan beni adalah : 89700.0
# maka jumlah kembalian beni adalah : 60300.0
#
# citra
# maka total belanjaan citra adalah : 56000
# maka kembalian citra adalah : 4000
#
# dadang
# maka total belanjaan dadang adalah : 66400.0
# maka jumlah kembalian beni adalah : 33600.0
#
# epen
# maka total belanjaan dadang adalah : 89300.0
# maka jumlah kembalian beni adalah : 10700.0
#
#      soal 4
# maka jumlah potongan ahmad adalah : 65000.0
#
# maka jumlah potongan beni adalah : 59500.0
#
# maka jumlah potongan citra adalah : 14000.0
#
# maka jumlah potongan dadang adalah : 14000.0
#
# ...
