# %%
import statistics
import pandas as pd
import numpy as np
from scipy import stats

# %%
beras = 11400 #Per Kg
minyak = 12700 #per Liter
ayam = 3400 #per 100 gram
telur = 21800 #per 1Kg
popok = 27000 #per pcs
sabun_cuci = 1800 #per 100gram
buah_anggur = 3800 #per 100gram
roti_tawar = 8500 #per 100gram
tishu = 6400 #per pcs
mie_instan = 2200 #per pcs

print("")
#Tia
print("belanjaan tia")
beras_tia = 4
ayam_tia = 2
telur_tia = 3
sabun_cuci_tia = 5
buah_anggur_tia = 4
roti_tawar_tia = 2
mie_instan_tia = 12

jb_tia = (beras_tia * beras) + (ayam_tia * ayam * 10) + (telur_tia * telur) + (sabun_cuci_tia * sabun_cuci) + (buah_anggur_tia * buah_anggur) + (roti_tawar_tia * roti_tawar) + (mie_instan_tia * mie_instan)
jb_diskon_tia = (jb_tia/100) * 85
print("maka jumlah belanjaan tia " + str(jb_tia) + " RP")
print("maka jumlah belanjaan tia setelah di diskon " + str(jb_diskon_tia))

print("")
#hana
print("jumlah belanja hana")
minyak_hana = 2
ayam_hana = 5
telur_hana = 1.5
sabun_hana = 3
anggur_hana = 8
roti_hana = 3
tishu_hana = 2 
mie_hana = 20
diskon = 90
jb_hana = (minyak_hana * minyak)+(ayam_hana * ayam)+(telur_hana * telur)+(sabun_hana * sabun_cuci)+(anggur_hana * buah_anggur)+(roti_hana * roti_tawar)+(tishu_hana * tishu)+(mie_hana * mie_instan)
jb_diskon_hana = (jb_hana/100) * diskon
print("maka jumlah belanjaan hana " + str(jb_hana) + " Rp")
print("maka jumlah belanjaan hana yang telah di diskon " + str(jb_diskon_hana))

print("")
#widia
print("jumlah belanja widia")
beras_widia = 1
minyak_widia = 1
telur_widia = 1
anggur_widia = 5
tishu_widia = 3
mie_widia = 16
jb_widia =(beras_widia * beras)+(minyak_widia * minyak)+(telur_widia * telur)+(anggur_widia * buah_anggur)+(tishu_widia * tishu)+(mie_widia * mie_instan)

print("maka jumlahb belanjaanya adalah " +str (jb_widia) + " Rp")

print("")
#romi
print("jumlah belanja romi")
minyak_romi = 3
telur_romi = 2
popok_romi = 4
sabun_romi = 8
mie_romi = 8 
diskon = 85
jb_romi = (minyak_romi * minyak)+(telur_romi * telur)+(popok_romi * popok)+(sabun_romi * sabun_cuci)+(mie_romi * mie_instan)
jb_diskon_romi = (jb_romi/100) * diskon
print("maka jumlah belanja romi " +str (jb_romi) + " Rp")           
print("maka jumlah belanja romi setelah di diskon " +str(jb_diskon_romi))

print("")
#samsul
print("jumlah belanja samsul")
ayam_samsul = 3
telur_samsul = 4
popok_samsul = 2
buah_samsul = 7
tishu_samsul = 5
mie_samsul = 10
dikon = 75

jb_samsul = (ayam_samsul * (ayam * 10)) + (telur_samsul * telur)+(popok_samsul * popok)+(buah_samsul * buah_anggur)+(tishu_samsul * tishu)+(mie_samsul * mie_instan)
jb_diskon_samsul = (jb_samsul/100) * 75
print("maka jumlah belanja samsul " +str (jb_samsul) +" rupiah")
print("maka jumlah belanja samsul setelah di diskon " +str(jb_diskon_samsul))

print("")
#dimas
print("jumlah belanja dimas")
ayam_dimas = 5
popok_dimas = 5
sabun_dimas = 4
buah_dimas = 3
roti_dimas = 5
mie_dimas = 6
dikon = 75

jb_dimas = (ayam_dimas * (ayam * 10)) + (popok_dimas * popok)+(sabun_dimas * sabun_cuci)+(buah_dimas * buah_anggur)+(roti_dimas * roti_tawar)+(mie_dimas * mie_instan)
jb_diskon_dimas = (jb_dimas/100) * 75
print("maka jumlah belanja  dimas " +str (jb_dimas) +" rupiah")
print("maka jumlah belanja dimas seetelah di pakai diskon " +str (jb_diskon_dimas) +" rupiah")

print("")


print()
maxz = [284475]
print("maka jumlah belanjaaan paling besar setelah diskon adalah adalah rp. " +str(maxz))

terpersen = {"hana" : "rp.173880"}
print("maka yang belanjaan nya mendafat diskon 10% adalah : "  + str (terpersen))
# Out:
# belanjaan tia
# maka jumlah belanjaan tia 246600 RP
# maka jumlah belanjaan tia setelah di diskon 209610.0
#
# jumlah belanja hana
# maka jumlah belanjaan hana 193200.0 Rp
# maka jumlah belanjaan hana yang telah di diskon 173880.0
#
# jumlah belanja widia
# maka jumlahb belanjaanya adalah 119300 Rp
#
# jumlah belanja romi
# maka jumlah belanja romi 221700 Rp
# maka jumlah belanja romi setelah di diskon 188445.0
#
# jumlah belanja samsul
# maka jumlah belanja samsul 323800 rupiah
# maka jumlah belanja samsul setelah di diskon 242850.0
#
# jumlah belanja dimas
# maka jumlah belanja  dimas 379300 rupiah
# maka jumlah belanja dimas seetelah di pakai diskon 284475.0 rupiah
#
# maka jumlah belanjaaan paling besar setelah diskon adalah adalah rp. [284475]
# maka yang belanjaan nya mendafat diskon 10% adalah : {'hana': 'rp.173880'}
