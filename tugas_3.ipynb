# %%
import statistics
import pandas as pd
import numpy as np
from scipy import stats

import matplotlib.pyplot as plt

# %%
print(" soal 1 ")
print()

# grafik batang 
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
pen = ['paskibra', 'pmr', 'pramuka', 'putsal', 'voly', 'kesenian', 'rohis',]
jml = [5, 18, 30, 7, 16, 19, 12]
c = ['blue', 'orange', 'green', 'red', 'purple', 'brown']
plt.title("JUMLAH SISWA YANG MENGIKUTI ESKUL ")
plt.bar(pen, jml, color = c)
plt.show()
print()

print(" soal 2 ")

# grafik batang 
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
pen = ['paskibra', 'pmr', 'pramuka', 'putsal', 'voly', 'kesenian', 'rohis',]
jml = [32, 34, 62, 51, 38, 41, 29]
c = ['blue', 'orange', 'green', 'red', 'purple', 'brown']
plt.title("JUMLAH SISWA YANG MENGIKUTI DI SETIAP ESKULNYA ")
plt.bar(pen, jml, color = c)
plt.show()
print()

print("soal 3")

futsal_a = 7
futsal_b = 29
futsal_c = 15
voly_a = 16
voly_b = 10
voly_c = 12
m = 287
tm = 45
hasilf = futsal_a + futsal_b + futsal_c + voly_a + voly_b +voly_c
print("maka yang ikut eskul olahraga adalah : " + str (hasilf))
hasilnya = m - hasilf
print("niai baru yang mengikuti eskul adalah : " + str (hasilnya))
print("yang tidak mengikuti eskul adalah : " + str (tm))
hasilf1 = (tm / 332) * 100
hasilf2 = (hasilf / 332) * 100
hasilf3 = (hasilnya / 332) * 100
print("yang tidak mengikuti eskul adalah : " + str (hasilf1))
print("yang tidak mengikuti eskul adalah : " + str (hasilf2))
print("yang tidak mengikuti eskul adalah : " + str (hasilf3))
print()


# grafik batang soal 3
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
pen = [ 'olahraga', 'tidak mengikuti', 'mengikuti',]
jml = [13.55, 26.80, 59.63]
c = ['blue', 'orange', 'green', 'red', 'purple', 'brown']
plt.title("Hasil presentase bar ")
plt.bar(pen, jml, color = c)
plt.show()
print()

# PIECART soal 3
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("hasil presentasi piechar")
jurusan = [ 'olahraga', 'tidak mengikuti', 'mengikuti',]
siswa = [13.55, 26.80, 59.63]
ax.pie(siswa,labels=jurusan,autopct='%1.2f%%')
plt.show()
print()


print("soal 4")
k10 = 17
k11 = 8
k12 = 20
index = 45

hasil10 = (k10 / index) * 10
hasil11 = (k11 / index) * 10
hasil12 = (k12 / index) * 10
print("maka hasil siswa yang tidak mengikuti eskul kelas 10 adalah : " + str (hasil10))
print("maka hasil siswa yang tidak mengikuti eskul kelas 11 adalah : " + str (hasil11))
print("maka hasil siswa yang tidak mengikuti eskul kelas 12 adalah : " + str (hasil12))
print()


# PIECART 12
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("jumlah siswa yang tidak mengikuti eskul")
jurusan = ['kelas 10', 'kelas 11', 'kelas 12',]
siswa = [3.7, 1.7, 4.4]
ax.pie(siswa,labels=jurusan,autopct='%1.2f%%')
plt.show()
print()


print("soal 5")
# grafik batang 10
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
pen = ['paskibra', 'pmr', 'pramuka', 'putsal', 'voly', 'kesenian', 'rohis',]
jml = [5, 18, 30, 7, 16, 19, 12]
c = ['blue', 'orange', 'green', 'red', 'purple', 'brown']
plt.title("JUMLAH SISWA YANG MENGIKUTI ESKUL KELAS 10 ")
plt.bar(pen, jml, color = c)
plt.show()
print()

# PIECART 10
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("JUMLAH SISWA YANG MENGIKUTI ESKUL KELAS 10")
jurusan = ['paskibra', 'pmr', 'pramuka', 'putsal', 'voly', 'kesenian', 'rohis',]
siswa = jml = [5, 18, 30, 7, 16, 19, 12]
ax.pie(siswa,labels=jurusan,autopct='%1.2f%%')
plt.show()
print()

# grafik batang 11
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
pen = ['paskibra', 'pmr', 'pramuka', 'putsal', 'voly', 'kesenian', 'rohis',]
jml = [21, 4, 8, 29, 10, 18, 10, ]
c = ['blue', 'orange', 'green', 'red', 'purple', 'brown']
plt.title("JUMLAH SISWA YANG MENGIKUTI ESKUL KELAS 11 ")
plt.bar(pen, jml, color = c)
plt.show()
print()

# PIECART 11
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("JUMLAH SISWA YANG MENGIKUTI ESKUL KELAS 11")
jurusan = ['paskibra', 'pmr', 'pramuka', 'putsal', 'voly', 'kesenian', 'rohis',]
siswa = [21, 4, 8, 29, 10, 18, 10, ]
ax.pie(siswa,labels=jurusan,autopct='%1.2f%%')
plt.show()
print()

# grafik batang 12
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
pen = ['paskibra', 'pmr', 'pramuka', 'putsal', 'voly', 'kesenian', 'rohis',]
jml = [6, 12, 24, 15, 12, 4, 7]
c = ['blue', 'orange', 'green', 'red', 'purple', 'brown']
plt.title("JUMLAH SISWA YANG MENGIKUTI ESKUL KELAS 12 ")
plt.bar(pen, jml, color = c)
plt.show()
print()

# PIECART 12
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("JUMLAH SISWA YANG MENGIKUTI ESKUL KELAS 12")
jurusan = ['paskibra', 'pmr', 'pramuka', 'putsal', 'voly', 'kesenian', 'rohis',]
siswa = [6, 12, 24, 15, 12, 4, 7]
ax.pie(siswa,labels=jurusan,autopct='%1.2f%%')
plt.show()
print()
# Out:
#  soal 1
#  soal 2
# soal 3
# maka yang ikut eskul olahraga adalah : 89
# niai baru yang mengikuti eskul adalah : 198
# yang tidak mengikuti eskul adalah : 45
# yang tidak mengikuti eskul adalah : 13.55421686746988
# yang tidak mengikuti eskul adalah : 26.80722891566265
# yang tidak mengikuti eskul adalah : 59.63855421686747
# soal 4
# maka hasil siswa yang tidak mengikuti eskul kelas 10 adalah : 3.7777777777777777
# maka hasil siswa yang tidak mengikuti eskul kelas 11 adalah : 1.777777777777778
# maka hasil siswa yang tidak mengikuti eskul kelas 12 adalah : 4.444444444444445
# soal 5
