# %%
import statistics
import pandas as pd
import numpy as np
from scipy import stats

import matplotlib.pyplot as plt

# %%
a_xis = 20
b_log = 14
c_in = 28
d_namic = 42
e_psilon = 18

print("     soal 1")
axis1 = (a_xis * 300000) + (a_xis * 75000)
print("maka gaji yang di keluarkan adalah : " +str(axis1))
blog1 = (b_log * 360000) + (b_log * 75000)
print("maka gaji yang di keluarkan adalah : " +str(blog1))
cin1 = (c_in * 475000) + (c_in * 75000)
print("maka gaji yang di keluarkan adalah : " +str(cin1))
dnamic1 = (d_namic * 580000) + (d_namic * 75000)
print("maka gaji yang di keluarkan adalah : " +str(dnamic1))
epsilon1 = (e_psilon * 400000) + (e_psilon * 75000)
print("maka gaji yang di keluarkan adalah : " +str(axis1))
print()

print("     soal 2")
laba_a = 32500000
laba_b = 31000000
laba_c = 42000000
laba_d = 51500000
laba_e = 27000000

utang_a = 0.08
utang_b = 0.04
utang_c = 0.12
utang_d = 0.11
utang_e = 0.03
print()

pajak = 0.03
pertahun = 12
jlma = ((laba_a * pajak) + (utang_a * 280000000 ))
print("maka total pajak dan hutang a adalah  Rp." +str(jlma))
jlmb = (laba_b * pajak) + (utang_b * 310000000)
print("maka total pajak dan utang b adalah Rp." +str(jlmb))
jlmc = (laba_c * pajak) + (utang_c * 420000000)
print("maka total pajak dan utang c adalah Rp." +str(jlmc))
jlmd = (laba_d * pajak) + (utang_d * 550000000)
print("maka total pajak dan utang d adalah Rp." +str(jlmd))
jlme = (laba_e * pajak) + (utang_e * 340000000)
print("maka total pajak dan utang e adalah Rp." +str(jlme))
print()

# PIECART
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("pajak dan hutang")
jurusan = ['A-xis', 'B-log', 'C-in', 'D-namic', 'E-psilon']
siswa = [23375000.0, 13330000.0, 51660000.0, 62045000.0, 11010000.0 ]
ax.pie(siswa,labels=jurusan,autopct='%1.2f%%')
plt.show()
print()

# grafik batang 
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
jurusan = ['A-xis', 'B-log', 'C-in', 'D-namic', 'E-psilon']
siswa = [23375000.0, 13330000.0, 51660000.0, 62045000.0, 11010000.0 ]
c = ['blue', 'orange', 'green', 'red', 'purple', 'brown']
plt.title("JUMLAH BELANJAAN")
plt.bar(jurusan, siswa, color = c)
plt.show()
print()

print("     soal 3")
aset1 = 280000000
aset2 = 310000000
aset3 = 420000000
aset4 = 550000000
aset5 = 340000000
csr = 0.025
csr1 = 0.035
hasil1 = aset1 * csr
print("maka csr perusahaan a adalah : " +str (hasil1))
hasil2 = aset2 * csr1
print("maka csr perusahaan a adalah : " +str (hasil2))
hasil3 = aset3 * csr1
print("maka csr perusahaan a adalah : " +str (hasil3))
hasil4 = aset4 * csr1
print("maka csr perusahaan a adalah : " +str (hasil4))
hasil5 = aset5 * csr1
print("maka csr perusahaan a adalah : " +str (hasil5))
print()

# PIECART
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("pajak dan hutang")
jurusan = ['A-xis', 'B-log', 'C-in', 'D-namic', 'E-psilon']
siswa = [7000000.0, 10850000.000000002, 14700000.000000002, 19250000.0, 11900000.000000002]
ax.pie(siswa,labels=jurusan,autopct='%1.2f%%')
plt.show()
print()

print("     soal 4")
hasila = (laba_a * 12)
print("maka total laba di perusahaan A-xis adalah : " +str(hasila))
hasilb = (laba_b * 12)
print("maka total laba di perusahaan B-log adalah : " +str(hasilb))
hasilc = (laba_c * 12)
print("maka total laba di perusahaan C-in adalah : " +str(hasilc))
hasild = (laba_d * 12)
print("maka total laba di perusahaan D-namic adalah : " +str(hasild))
hasile = (laba_e * 12)
print("maka total laba di perusahaan E-psilon adalah : " +str(hasile))
hs = (hasila + hasilb + hasilc + hasild + hasile)
print("maka hasil seluruh laba perusahaan adalah : " +str(hs))
print()

print("     soal 5")
hasil_a = (laba_a * 12) - csr * 280000000 - (7500000 * 12 ) - 23375000.0
print("maka total hasil : " +str(hasil_a))
hasil_b = (laba_b * 12) - csr1 * 310000000 - (6090000 * 12 ) - 13330000.0
print("maka total hasil : " +str(hasil_b))
hasil_c = (laba_c * 12) - csr1 * 420000000 - (15400000 * 12 ) - 51660000.0
print("maka total hasil : " +str(hasil_c))
hasil_d = (laba_d * 12) - csr1 * 550000000 - (27510000 * 12 ) - 62045000.0
print("maka total hasil : " +str(hasil_d))
hasil_e = (laba_e * 12) - csr1 * 340000000 - (7500000 * 12 ) - 11010000.0
print("maka total hasil : " +str(hasil_e))
print()

# PIECART
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("pendapatan bersih tiap perusahaan")
jurusan = ['A-xis', 'B-log', 'C-in', 'D-namic', 'E-psilon']
siswa = [ 269625000.0, ]
ax.pie(siswa,labels=jurusan,autopct='%1.2f%%')
plt.show()
print()
# Out:
#      soal 1
# maka gaji yang di keluarkan adalah : 7500000
# maka gaji yang di keluarkan adalah : 6090000
# maka gaji yang di keluarkan adalah : 15400000
# maka gaji yang di keluarkan adalah : 27510000
# maka gaji yang di keluarkan adalah : 7500000
#
#      soal 2
#
# maka total pajak dan hutang a adalah  Rp.23375000.0
# maka total pajak dan utang b adalah Rp.13330000.0
# maka total pajak dan utang c adalah Rp.51660000.0
# maka total pajak dan utang d adalah Rp.62045000.0
# maka total pajak dan utang e adalah Rp.11010000.0
#      soal 3
# maka csr perusahaan a adalah : 7000000.0
# maka csr perusahaan a adalah : 10850000.000000002
# maka csr perusahaan a adalah : 14700000.000000002
# maka csr perusahaan a adalah : 19250000.0
# maka csr perusahaan a adalah : 11900000.000000002
#      soal 4
# maka total laba di perusahaan A-xis adalah : 390000000
# maka total laba di perusahaan B-log adalah : 372000000
# maka total laba di perusahaan C-in adalah : 504000000
# ...
